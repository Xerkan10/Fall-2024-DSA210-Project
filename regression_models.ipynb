# %%
import glob
import pandas as pd

# Get a list of all files matching the pattern
file_list = glob.glob('data/parsed_data/heroes_matches_csv/heroes_matches_batch_*.csv')

# Initialize an empty dataframe to store the results
result_df = pd.DataFrame()

# Iterate through each file
for file in file_list:
    # Load the data
    temp_df = pd.read_csv(file)
    
    # Filter columns starting with 'A' and 'B' and include 'duration'
    filtered_df = temp_df.filter(regex='^(duration|[AE])')
    
    # Append the filtered data to the result dataframe
    result_df = pd.concat([result_df, filtered_df], ignore_index=True)

# Display the result dataframe
print(result_df)
# Initialize an empty list to store the new rows
new_rows = []

# Iterate through each match (row in the original dataset)
for _, match_row in result_df.iterrows():
    for prefix in ['A', 'E']:  # Iterate through teams (A and B)
        for i in range(1, 6):  # Iterate through players (1 to 5)
            # Create a new row for each player
            player_data = {}
            for col in match_row.index:
                if col.startswith(f'{prefix}{i}_'):  # Filter columns for the specific player
                    # Rename column by removing prefix (e.g., A1_kills -> kills)
                    new_col_name = col[len(f'{prefix}{i}_'):]
                    player_data[new_col_name] = match_row[col]
            
            # Add team information
            player_data['duration'] = match_row['duration']
            new_rows.append(player_data)

# Create a new dataframe from the new rows
final_df = pd.DataFrame(new_rows)

# Display the final dataframe
print(final_df)
print(len(file_list))
# Out:
#       duration  A1_hero_id  A1_kills  A1_deaths  A1_assists  A1_gold_per_min  \
# 0         3103          84         9         12          12              448
# 1         1827          98         5          5          16             1088
# 2         1728          47         7          8          13              884
# 3         1242          37         1          1          32              993
# 4         1318          63         9          5           6              961
# ...        ...         ...       ...        ...         ...              ...
# 4685      2567          23         4         13           4              394
# 4686      1454          37         3          8           6              677
# 4687      2468          38         4         13           8              444
# 4688      2005         108         1          7           7              405
# 4689      1338          67         5          2          12             1080
#
#       A1_xp_per_min  A1_win  A1_performance  A1_normalized_performance  ...  \
# 0               533       1          0.2818                   0.194156  ...
# 1              2197       1          0.4950                   0.215444  ...
# 2              1507       0          0.4983                   0.301279  ...
# 3              1956       1          0.8294                   0.478885  ...
# 4              1555       0          0.4688                   0.243750  ...
# ...             ...     ...             ...                        ...  ...
# 4685            472       0          0.0928                   0.095127  ...
# 4686           1241       0          0.1933                   0.183613  ...
# 4687            539       0          0.1704                   0.198355  ...
# 4688            476       0          0.3184                   0.200096  ...
# 4689           1711       1          0.4651                   0.180578  ...
#
#       E5_xp_per_min  E5_win  E5_performance  E5_normalized_performance  \
# 0              1187       0          0.6823                   0.362193
# 1              1532       0          0.5554                   0.275763
# 2              1966       1          0.4680                   0.257912
# 3              1666       0          0.6419                   0.320541
# 4              1930       1          0.1042                   0.089062
# ...             ...     ...             ...                        ...
# 4685           1004       1          0.4347                   0.282675
# 4686           1571       1          0.1036                   0.103081
# 4687           1232       1          0.4477                   0.247268
# 4688            645       1          0.6151                   0.309463
# 4689            932       0          0.1949                   0.118115
#
#       E5_level  E5_net_worth  E5_team_score  E5_opponent_score  \
# 0           29         35566             55                 42
# 1           27         25979             31                 32
# 2           29         32860             33                 27
# 3           25         21494             16                 37
# 4           26         14157             32                 24
# ...        ...           ...            ...                ...
# 4685        26         24927             71                 29
# 4686        25         25590             34                 21
# 4687        28         31854             37                 23
# 4688        20         11928             46                 17
# 4689        19         16337             24                 31
#
#       E5_tower_damage  E5_hero_damage
# 0                6188          141596
# 1                 586           23015
# 2                2521           30866
# 3                 506           26485
# 4                 943            4997
# ...               ...             ...
# 4685             2791           34774
# 4686                0           25508
# 4687            16462           55883
# 4688             2900            7709
# 4689              237            6320
#
# [4690 rows x 151 columns]
#        hero_id  kills  deaths  assists  gold_per_min  xp_per_min  win  \
# 0         84.0    9.0    12.0     12.0         448.0       533.0  1.0
# 1         42.0    6.0     5.0      5.0         797.0      1072.0  1.0
# 2         45.0   11.0     9.0     13.0         414.0       742.0  1.0
# 3         78.0   11.0    13.0     18.0         594.0      1164.0  1.0
# 4         36.0    5.0    16.0     23.0         430.0       626.0  1.0
# ...        ...    ...     ...      ...           ...         ...  ...
# 46895    145.0    6.0     6.0     11.0         969.0      1219.0  0.0
# 46896     76.0   11.0     7.0      6.0        1040.0      1408.0  0.0
# 46897    100.0    5.0     5.0     10.0         855.0      1422.0  0.0
# 46898     84.0    1.0    10.0     11.0         826.0      1292.0  0.0
# 46899     89.0    1.0     3.0      6.0         753.0       932.0  0.0
#
#        performance  normalized_performance  level  net_worth  team_score  \
# 0           0.2818                0.194156   22.0    19970.0        42.0
# 1           0.1710                0.103175   28.0    37014.0        42.0
# 2           0.4078                0.217121   26.0    21103.0        42.0
# 3           0.4541                0.276931   29.0    25591.0        42.0
# 4           0.3758                0.199169   24.0    19313.0        42.0
# ...            ...                     ...    ...        ...         ...
# 46895       0.5148                0.234879   22.0    20684.0        24.0
# 46896       0.4825                0.276855   24.0    22185.0        24.0
# 46897       0.4637                0.263978   24.0    18567.0        24.0
# 46898       0.1774                0.194052   23.0    18559.0        24.0
# 46899       0.1949                0.118115   19.0    16337.0        24.0
#
#        opponent_score  tower_damage  hero_damage  duration
# 0                55.0         399.0      26295.0    3103.0
# 1                55.0       16667.0      22606.0    3103.0
# 2                55.0         478.0      28962.0    3103.0
# 3                55.0        5777.0      99410.0    3103.0
# 4                55.0         320.0      41941.0    3103.0
# ...               ...           ...          ...       ...
# 46895            31.0        1552.0      21729.0    1338.0
# 46896            31.0           0.0      23893.0    1338.0
# 46897            31.0           0.0      15609.0    1338.0
# 46898            31.0           0.0      14328.0    1338.0
# 46899            31.0         237.0       6320.0    1338.0
#
# [46900 rows x 16 columns]
# 24

# %%
final_df.head(20)
# Out:
#     hero_id  kills  deaths  assists  gold_per_min  xp_per_min  win  \
# 0      84.0    9.0    12.0     12.0         448.0       533.0  1.0
# 1      42.0    6.0     5.0      5.0         797.0      1072.0  1.0
# 2      45.0   11.0     9.0     13.0         414.0       742.0  1.0
# 3      78.0   11.0    13.0     18.0         594.0      1164.0  1.0
# 4      36.0    5.0    16.0     23.0         430.0       626.0  1.0
# 5      34.0    6.0     6.0     20.0         384.0       698.0  0.0
# 6     111.0    6.0     8.0     21.0         701.0       879.0  0.0
# 7      72.0    4.0    11.0     19.0         410.0       591.0  0.0
# 8     131.0    4.0     9.0     36.0         440.0       980.0  0.0
# 9       8.0   34.0     8.0     14.0         845.0      1187.0  0.0
# 10     98.0    5.0     5.0     16.0        1088.0      2197.0  1.0
# 11     66.0    5.0     5.0     19.0         998.0      1949.0  1.0
# 12     41.0    6.0     5.0     13.0        1345.0      2175.0  1.0
# 13     21.0   12.0     7.0      7.0        1218.0      1787.0  1.0
# 14      2.0    4.0     9.0     13.0         966.0      1488.0  1.0
# 15    135.0    9.0     5.0     14.0        1191.0      2204.0  0.0
# 16     27.0    0.0     7.0     18.0         586.0      1560.0  0.0
# 17     14.0    6.0     9.0     16.0         966.0      1602.0  0.0
# 18     94.0    9.0     4.0     12.0        1208.0      1986.0  0.0
# 19     74.0    7.0     7.0     17.0         890.0      1532.0  0.0
#
#     performance  normalized_performance  level  net_worth  team_score  \
# 0        0.2818                0.194156   22.0    19970.0        42.0
# 1        0.1710                0.103175   28.0    37014.0        42.0
# 2        0.4078                0.217121   26.0    21103.0        42.0
# 3        0.4541                0.276931   29.0    25591.0        42.0
# 4        0.3758                0.199169   24.0    19313.0        42.0
# 5        0.3299                0.151948   25.0    16695.0        55.0
# 6        0.3004                0.190628   27.0    30501.0        55.0
# 7        0.1563                0.088857   23.0    18238.0        55.0
# 8        0.5130                0.288545   28.0    15445.0        55.0
# 9        0.6823                0.362193   29.0    35566.0        55.0
# 10       0.4950                0.215444   30.0    31508.0        32.0
# 11       0.5887                0.386996   29.0    29114.0        32.0
# 12       0.4325                0.242339   30.0    40221.0        32.0
# 13       0.3679                0.222379   28.0    36899.0        32.0
# 14       0.2409                0.216353   27.0    29932.0        32.0
# 15       0.5857                0.295296   30.0    32939.0        31.0
# 16       0.3619                0.275027   27.0    19138.0        31.0
# 17       0.4284                0.295968   27.0    30304.0        31.0
# 18       0.5524                0.256774   29.0    36403.0        31.0
# 19       0.5554                0.275763   27.0    25979.0        31.0
#
#     opponent_score  tower_damage  hero_damage  duration
# 0             55.0         399.0      26295.0    3103.0
# 1             55.0       16667.0      22606.0    3103.0
# 2             55.0         478.0      28962.0    3103.0
# 3             55.0        5777.0      99410.0    3103.0
# 4             55.0         320.0      41941.0    3103.0
# 5             42.0         730.0      50621.0    3103.0
# 6             42.0        1208.0      67604.0    3103.0
# 7             42.0         424.0      32475.0    3103.0
# 8             42.0          51.0      21188.0    3103.0
# 9             42.0        6188.0     141596.0    3103.0
# 10            31.0        1283.0      18098.0    1827.0
# 11            31.0       10737.0      17297.0    1827.0
# 12            31.0        3895.0      26261.0    1827.0
# 13            31.0        3594.0      36884.0    1827.0
# 14            31.0        3200.0      22386.0    1827.0
# 15            32.0        3928.0      37850.0    1827.0
# 16            32.0           0.0      10982.0    1827.0
# 17            32.0         710.0      37771.0    1827.0
# 18            32.0        6778.0      36615.0    1827.0
# 19            32.0         586.0      23015.0    1827.0

# %%
import numpy as np
def log_mse_calculate(y_true, y_pred):
  """
  Calculate the Log Mean Squared Error (Log MSE) for like counts (log(like_count + 1)).

  Parameters:
  - y_true: array-like, actual like counts
  - y_pred: array-like, predicted like counts

  Returns:
  - log_mse: float, Log Mean Squared Error
  """
  # Ensure inputs are numpy arrays
  y_true = np.array(y_true)
  y_pred = np.array(y_pred)

  # Log transformation: log(like_count + 1)
  log_y_true = np.log1p(y_true)
  log_y_pred = np.log1p(y_pred)

  # Compute squared errors
  squared_errors = (log_y_true - log_y_pred) ** 2

  # Return the mean of squared errors
  return np.mean(squared_errors)

# %% [markdown]
# ## FIRST PART
# -Now I will form a model which will predict tower_damage

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Preprocess the data
# Assuming 'tower_damage' is the target variable and the rest are features
X = final_df.drop(columns=['tower_damage', 'hero_id', 'normalized_performance', 'kills', 'deaths', 'assists', 'hero_damage']) # Drop columns that are not needed to train the model. 
#hero_damage is dropped because it's not present in my matches(I am trying to predict tower damage in my matches).

y = final_df['tower_damage']

# Convert y values to log form in order not to be skewed by outliers
y_log = np.log1p(y)

# Split the data into training and testing sets
X_train, X_val, y_train, y_val = train_test_split(X, y_log, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Define the parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [20, 30, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True]
}

# Initialize the GridSearchCV object
grid_search = GridSearchCV(estimator=RandomForestRegressor(random_state=42),
                           param_grid=param_grid,
                           cv=3,
                           n_jobs=-1,
                           verbose=2,
                           scoring='neg_mean_squared_error')

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Get the best parameters and the best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print(f'Best Parameters: {best_params}')
print(f'Best Score: {best_score}')
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   8.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   8.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   8.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   6.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   6.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   7.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  13.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  13.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  29.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   6.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   6.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   6.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  28.5s
# /Users/monsieurerkan/Desktop/vscode_projects/DSA210_Project/venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  27.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  28.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   6.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   6.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   6.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  27.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  26.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  25.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   6.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  26.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   6.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   6.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  26.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  25.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   6.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   6.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  26.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   6.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  12.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  25.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  25.7s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  12.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  12.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   5.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   5.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   6.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  26.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  23.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  26.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   5.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  23.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   7.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   7.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  14.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  21.7s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   5.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  28.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  28.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   7.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   5.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  12.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  13.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  27.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  20.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  13.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  27.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   7.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   7.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   8.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  20.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  25.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   7.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  24.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   6.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   7.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   6.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   6.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   6.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  29.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  29.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   7.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   7.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   7.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  29.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  25.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  29.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   6.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   6.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  28.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   7.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  28.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  27.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  26.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  14.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   7.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   7.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   7.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  13.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  13.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  28.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  28.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  13.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   6.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   6.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   5.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  28.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  25.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  25.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   6.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   6.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   6.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  26.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  12.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  23.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  23.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  12.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   6.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  24.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   6.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   5.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  23.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  23.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  24.0s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   7.6s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   7.6s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   7.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  23.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  23.6s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.0s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  23.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   7.0s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.2s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   6.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   7.2s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.3s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  31.1s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   7.2s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   7.1s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  31.1s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   6.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  28.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  29.1s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   6.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   6.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   6.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  28.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  26.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  26.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   6.6s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  26.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   6.6s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  26.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  26.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.2s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.3s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   6.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   6.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   6.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  27.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  12.6s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  26.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  26.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  13.1s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  13.0s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   6.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   6.3s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  26.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.0s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  25.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  25.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.1s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.3s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   6.0s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   6.0s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  26.2s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   5.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  23.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  24.1s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   6.1s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  24.0s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   6.1s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   6.2s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  12.1s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  23.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  24.1s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  23.3s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  21.2s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  21.2s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  20.4s
# Best Parameters: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Best Score: -4.406383405647478

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Train a RandomForestRegressor model with the best parameters from GridSearchCV
model = RandomForestRegressor(**best_params, random_state=42)
model.fit(X_train, y_train)

# Make predictions
y_pred_log = model.predict(X_val)

# Convert predictions back to original scale
y_pred = np.expm1(y_pred_log)

# Evaluate the model using log mean squared error
log_mse = log_mse_calculate(y_val, y_pred_log)
print(f'Log Mean Squared Error: {log_mse}')

# Calculate and print R^2 score
r2 = r2_score(np.expm1(y_val), y_pred)
print(f'R^2 Score: {r2}')
# Out:
# Log Mean Squared Error: 0.4084544279414639
# R^2 Score: 0.4912709308532357

# %%
from sklearn.model_selection import cross_val_score

# Initialize the RandomForestRegressor model with the best parameters from GridSearchCV
model = RandomForestRegressor(**best_params, random_state=42)

# Perform cross-validation
cv_scores = cross_val_score(model, X, y_log, cv=5, scoring='neg_mean_squared_error')

# Calculate the mean and standard deviation of the cross-validation scores
mean_cv_score = -np.mean(cv_scores)
std_cv_score = np.std(cv_scores)

print(f'Mean Cross-Validation Score: {mean_cv_score}')
print(f'Standard Deviation of Cross-Validation Score: {std_cv_score}')
# Out:
# Mean Cross-Validation Score: -4.576466982960329
# Standard Deviation of Cross-Validation Score: 0.09236216954869056

# %% [markdown]
# ## SECOND PART
# -Now I will form a model which will predict hero_damage

# %%
from sklearn.model_selection import train_test_split

# Preprocess the data
# Assuming 'tower_damage' is the target variable and the rest are features
X_damage = final_df.drop(columns=['tower_damage', 'hero_id', 'normalized_performance','hero_damage']) # Drop columns that are not needed to train the model. 
#hero_damage is dropped because it's not present in my matches(I am trying to predict tower damage in my matches).

y_damage = final_df['hero_damage']

# Convert y values to log form
y_damage_log = np.log1p(y_damage)

# Split the data into training and testing sets
X_damage_train, X_damage_val, y_damage_train, y_damage_val = train_test_split(X_damage, y_damage_log, test_size=0.2, random_state=42)

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Train a RandomForestRegressor model with the best parameters from GridSearchCV
model_damage = RandomForestRegressor(**best_params, random_state=42)
model_damage.fit(X_damage_train, y_damage_train)

# Make predictions
y_damage_pred_log = model_damage.predict(X_damage_val)

# Convert predictions back to original scale
y_damage_pred = np.expm1(y_damage_pred_log)

# Evaluate the model using log mean squared error
log_mse_damage = log_mse_calculate(y_damage_val, y_damage_pred_log)
print(f'Log Mean Squared Error: {log_mse_damage}')

# Calculate and print R^2 score
r2_damage = r2_score(np.expm1(y_damage_val), y_damage_pred)
print(f'R^2 Score: {r2_damage}')
# Out:
# Log Mean Squared Error: 0.002229542990831553
# R^2 Score: 0.7706174336317602

# %% [markdown]
# # PREDICTION FOR MY MATCHES
# - There's no way to find out how the model performs for my matches since tower_damage and hero_damage features are missing for most of them. But the purpose is just to fill these empty features in my matches, this will not be used elsewhere in this project.
